# %%
class car(): 
    #instantiation method:
    def __init__(self,name,model,colour,backseats,autodrive): 
        
        #ATTRIBUTES
        self.name=name 
        self.model=model 
        self.colour=colour 
        self.backseats=backseats 
        self.autodrive=autodrive

              # # # # #  #
             #METHOD_no1#
            # # # # # ##
    def speed(self):
        if self.name == "BMW":
            print(self.name, "Can cover 1.5 Kilometers per litre")
        elif self.name == "Lamborghini":
            print(self.name, "Can cover 3 Kilometers per litre ")
        elif self.name == "Marcedes":
            print(self.name, "Can cover 2 Kilometers per litre ")
        elif self.name == "Audi":
            print(self.name, "Can cover 2 Kilometers per litre ")
        else:
            print(self.name, "Can cover Approx. 1 Kilometer per litre ")
            
              # # # # #  #
             #METHOD_no2#
            # # # # # ##
    def updatecolour(self,colour):
        self.colour=colour
        
        
              # # # # #  #
             #METHOD_no3#
            # # # # # ##
    def compare(self,obj):
        if car1.autodrive == car5.autodrive:
            return True
        else:
            return False
    

    
#instances:
car1=car("BMW", "Virgo", "Black", "Yes", "NO") 
car2=car("Lamborghini", "Gallardo", "Yellow", "No", "Yes") 
car3=car("Cadillac","Cad-CT6","Grey","YES","NO")
car4=car("Ferrari","Ferrari Callifornia","RED","No","YES")
car5=car("Datsun","Dat-RediGO","Green","Yes","NO")

              

#Printing Each object info:
print("FIRST CAR\nName:", car1.name,"\nModel:", car1.model, "\nColour:", car1.colour, "\nBackseats: ", car1.backseats, "\nAutodrive Feature:", car1.autodrive)
print("\nSECOND CAR\nName:", car2.name,"\nModel:", car2.model, "\nColour:", car2.colour, "\nBackseats: ", car2.backseats, "\nAutodrive Feature:", car2.autodrive)
print("\nTHIRD CAR\nName:", car3.name,"\nModel:", car3.model, "\nColour:", car3.colour, "\nBackseats: ", car3.backseats, "\nAutodrive Feature:", car3.autodrive)
print("\nFOURTH CAR\nName:", car4.name,"\nModel:", car4.model, "\nColour:", car4.colour, "\nBackseats: ", car4.backseats, "\nAutodrive Feature:", car4.autodrive)
print("\nFIFTH CAR\nName:", car5.name,"\nModel:", car5.model, "\nColour:", car5.colour, "\nBackseats: ", car5.backseats, "\nAutodrive Feature:", car5.autodrive)

              
#APPLYING METHODS ON INSTANCES:

#Method_no1: (speed)
print("\nCar1's SPEED:")
car1.speed()
print("\nCar2's SPEED:")
car2.speed()

#Method_no2(ChangeName/UpdateName)
car1.updatecolour("INDIGO")
car2.updatecolour("Purple")

#Method_no3(compare)
print("\n\ncomparing Car1 and Car5 Autodrive Feature:")
if car1.compare(car5):
    print("\nAutordrive feature is same in both cars")
else:
    print("\nAutordrive feature is not same in both cars")

    
    
print("\n\nCar1's colour is changed to", car1.colour)
print("\n\nCar2's colour is chnaged to", car2.colour)
# Out:
# FIRST CAR
# Name: BMW
# Model: Virgo
# Colour: Black
# Backseats:  Yes
# Autodrive Feature: NO
#
# SECOND CAR
# Name: Lamborghini
# Model: Gallardo
# Colour: Yellow
# Backseats:  No
# Autodrive Feature: Yes
#
# THIRD CAR
# Name: Cadillac
# Model: Cad-CT6
# Colour: Grey
# Backseats:  YES
# Autodrive Feature: NO
#
# FOURTH CAR
# Name: Ferrari
# Model: Ferrari Callifornia
# Colour: RED
# Backseats:  No
# Autodrive Feature: YES
#
# FIFTH CAR
# Name: Datsun
# Model: Dat-RediGO
# Colour: Green
# Backseats:  Yes
# Autodrive Feature: NO
#
# Car1's SPEED:
# BMW Can cover 1.5 Kilometers per litre
#
# Car2's SPEED:
# Lamborghini Can cover 3 Kilometers per litre
#
#
# comparing Car1 and Car5 Autodrive Feature:
#
# Autordrive feature is same in both cars
#
#
# Car1's colour is changed to INDIGO
#
#
# Car2's colour is chnaged to Purple
